# %% [markdown]
# # Linear Regression
#
# https://github.com/chiphuyen/tf-stanford-tutorials/blob/master/examples/03_linear_regression_starter.py
#
# starter로 시작을 하겠지만 물론 정답도 같이 존재하긴 합니다...
# https://github.com/chiphuyen/tf-stanford-tutorials/blob/master/examples/03_linear_regression_sol.py

# %%
"""
Simple linear regression example in TensorFlow
This program tries to predict the number of thefts from 
the number of fire in the city of Chicago
"""

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import xlrd

DATA_FILE = 'data/fire_theft.xls'

# Phase 1: Assemble the graph
# Step 1: read in data from the .xls file
book = xlrd.open_workbook(DATA_FILE, encoding_override='utf-8')
sheet = book.sheet_by_index(0)
data = np.asarray([sheet.row_values(i) for i in range(1, sheet.nrows)])
n_samples = sheet.nrows - 1

# Step 2: create placeholders for input X (number of fire) and label Y (number of theft)


# Step 3: create weight and bias, initialized to 0
# name your variables w and b


# Step 4: predict Y (number of theft) from the number of fire
# name your variable Y_predicted


# Step 5: use the square error as the loss function
# name your variable loss

# Step 6: using gradient descent with learning rate of 0.01 to minimize loss
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001).minimize(loss)
 
# Phase 2: Train our model
with tf.Session() as sess:
	# Step 7: initialize the necessary variables, in this case, w and b
	# TO - DO	

	# Step 8: train the model
	for i in range(100): # run 100 epochs
		total_loss = 0
		for x, y in data:
			# Session runs optimizer to minimize loss and fetch the value of loss
			# TO DO: write sess.run()
			total_loss += l
		print "Epoch {0}: {1}".format(i, total_loss/n_samples)
	
# plot the results
# X, Y = data.T[0], data.T[1]
# plt.plot(X, Y, 'bo', label='Real data')
# plt.plot(X, X * w + b, 'r', label='Predicted data')
# plt.legend()
# plt.show()

# %% [markdown]
# ## 해봅시다

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import xlrd

DATA_FILE = 'data/fire_theft.xls'

# %% [markdown]
# ## Phase 1: Assemble the graph

# %% [markdown]
# ### Step 1: read in data from the .xls file

# %%
book = xlrd.open_workbook(DATA_FILE, encoding_override='utf-8')
sheet = book.sheet_by_index(0)
data = np.asarray([sheet.row_values(i) for i in range(1, sheet.nrows)])
n_samples = sheet.nrows - 1

# %% [markdown]
# xlrd는 excel파일을 쓰기 위한 library
# http://xlrd.readthedocs.io/en/latest/

# %%
data[:3], n_samples
# Out:
# (array([[  6.2,  29. ],
#         [  9.5,  44. ],
#         [ 10.5,  36. ]]), 42)

# %% [markdown]
# ### Step 2: create placeholders for input X (number of fire) and label Y (number of theft)

# %%
X = tf.placeholder(tf.float32, name='x')
Y = tf.placeholder(tf.float32, name='y')

# %% [markdown]
# ### Step 3: create weight and bias, initialized to 0
# ### name your variables w and b

# %%
w = tf.Variable(0.0, name='w')
b = tf.Variable(0.0, name='b')

# %% [markdown]
# ### Step 4: predict Y (number of theft) from the number of fire
# ### name your variable Y_predicted

# %%
y_predicted = w * X + b

# %% [markdown]
# ### Step 5: use the square error as the loss function
# ### name your variable loss

# %%
loss = tf.square(Y - y_predicted)

# %% [markdown]
# ### Step 6: using gradient descent with learning rate of 0.01 to minimize loss

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001).minimize(loss)

# %% [markdown]
# ## Phase 2: Train our model

# %% [markdown]
# ### Step 7: initialize the necessary variables, in this case, w and b

# %%
with tf.Session() as sess:
    # Step 7: initialize the necessary variables, in this case, w and b
    # TODO
    sess.run(tf.global_variables_initializer())
    
    for i in range(100):
        total_loss = 0
        for x, y in data:
            # Session runs optimizer to minimize loss and fetch the value of loss
            # TODO
            sess.run(optimizer, feed_dict={X:x, Y:y})
            
            #total_loss += l
        print ('Epoch {0}: {1}'.format(i, total_loss/n_samples))
# Out:
# Epoch 0: 0.0
# Epoch 1: 0.0
# Epoch 2: 0.0
# Epoch 3: 0.0
# Epoch 4: 0.0
# Epoch 5: 0.0
# Epoch 6: 0.0
# Epoch 7: 0.0
# Epoch 8: 0.0
# Epoch 9: 0.0
# Epoch 10: 0.0
# Epoch 11: 0.0
# Epoch 12: 0.0
# Epoch 13: 0.0
# Epoch 14: 0.0
# Epoch 15: 0.0
# Epoch 16: 0.0
# Epoch 17: 0.0
# Epoch 18: 0.0
# Epoch 19: 0.0
# Epoch 20: 0.0
# Epoch 21: 0.0
# Epoch 22: 0.0
# Epoch 23: 0.0
# Epoch 24: 0.0
# Epoch 25: 0.0
# Epoch 26: 0.0
# Epoch 27: 0.0
# Epoch 28: 0.0
# Epoch 29: 0.0
# Epoch 30: 0.0
# Epoch 31: 0.0
# Epoch 32: 0.0
# Epoch 33: 0.0
# Epoch 34: 0.0
# Epoch 35: 0.0
# Epoch 36: 0.0
# Epoch 37: 0.0
# Epoch 38: 0.0
# Epoch 39: 0.0
# Epoch 40: 0.0
# Epoch 41: 0.0
# Epoch 42: 0.0
# Epoch 43: 0.0
# Epoch 44: 0.0
# Epoch 45: 0.0
# Epoch 46: 0.0
# Epoch 47: 0.0
# Epoch 48: 0.0
# Epoch 49: 0.0
# Epoch 50: 0.0
# Epoch 51: 0.0
# Epoch 52: 0.0
# Epoch 53: 0.0
# Epoch 54: 0.0
# Epoch 55: 0.0
# Epoch 56: 0.0
# Epoch 57: 0.0
# Epoch 58: 0.0
# Epoch 59: 0.0
# Epoch 60: 0.0
# Epoch 61: 0.0
# Epoch 62: 0.0
# ...

# %% [markdown]
# ### Error
#
# total_loss += l 에서의 l
# plot에 필요한 w, b가 빠져있어서 그래프가 안그려진다.
# 다시...

# %%
with tf.Session() as sess:
    # Step 7: initialize the necessary variables, in this case, w and b
    # TODO
    sess.run(tf.global_variables_initializer())
    
    for i in range(100):
        total_loss = 0
        for x, y in data:
            # Session runs optimizer to minimize loss and fetch the value of loss
            # TODO
            _, l = sess.run([optimizer, loss], feed_dict={X:x, Y:y})
            
            total_loss += l
        print ('Epoch {0}: {1}'.format(i, total_loss/n_samples))
    
    w_v, b_v = sess.run([w, b])
# Out:
# Epoch 0: 2069.6319333978354
# Epoch 1: 2117.0123581953535
# Epoch 2: 2092.302723001866
# Epoch 3: 2068.5080461938464
# Epoch 4: 2045.591184088162
# Epoch 5: 2023.5146448101316
# Epoch 6: 2002.2447619835536
# Epoch 7: 1981.748338803649
# Epoch 8: 1961.9944411260742
# Epoch 9: 1942.9520116143283
# Epoch 10: 1924.5930823644712
# Epoch 11: 1906.8898800636332
# Epoch 12: 1889.8164505837929
# Epoch 13: 1873.347133841543
# Epoch 14: 1857.4588400604468
# Epoch 15: 1842.1278742424079
# Epoch 16: 1827.332495119955
# Epoch 17: 1813.0520579712022
# Epoch 18: 1799.2660847636982
# Epoch 19: 1785.9562132299961
# Epoch 20: 1773.1024853109072
# Epoch 21: 1760.689129482884
# Epoch 22: 1748.6984157081515
# Epoch 23: 1737.1138680398553
# Epoch 24: 1725.920873066732
# Epoch 25: 1715.1046249579008
# Epoch 26: 1704.6500954309377
# Epoch 27: 1694.5447134910141
# Epoch 28: 1684.7746311347667
# Epoch 29: 1675.328450968245
# Epoch 30: 1666.1935385839038
# Epoch 31: 1657.3584002084322
# ...

# %%
X, Y = data.T[0], data.T[1]
plt.plot(X, Y, 'bo', label='Real data')
#plt.plot(X, X * w + b, 'r', label='Predicted data')
plt.plot(X, X * w_v + b_v, 'r', label='Predicted data')
plt.legend()
plt.show()

# %% [markdown]
# 이거 그래프를 tensorboard 말고 digraph를 이용해서 jupyter에서 볼 순 없을까?
#
# plot 하느라 session을 여러번 돌려서 다시 초기화 할 필요는 있네요...
# tf.reset_default_graph() 를 실행해서 다시 돌려볼게요

# %%
#tf.reset_default_graph()

# %%
from graphviz import Digraph

# %%
dot = Digraph()

for n in tf.get_default_graph().as_graph_def().node:
    dot.node(n.name, label=n.name)
    
    for i in n.input:
        dot.edge(i, n.name)
        
dot

# %% [markdown]
# gradients 가 다 나오다 보니 굉장히 복잡하네요...
#
# 그냥 tensorboard를 실행해야겠습니다.
# 슬라이드 24페이지를 참조하세요.

# %%
with tf.Session() as sess:
    # Step 7: initialize the necessary variables, in this case, w and b
    # TODO
    sess.run(tf.global_variables_initializer())
    
    writer = tf.summary.FileWriter('./my_graph/03/linear_reg', sess.graph)
    
    for i in range(100):
        total_loss = 0
        for x, y in data:
            # Session runs optimizer to minimize loss and fetch the value of loss
            # TODO
            _, l = sess.run([optimizer, loss], feed_dict={X:x, Y:y})
            
            total_loss += l
        #print ('Epoch {0}: {1}'.format(i, total_loss/n_samples))
    
    w_v, b_v = sess.run([w, b])
    
    writer.close()

# %% [markdown]
# 저는 아래와 같이 슬라이드와 같이 나왔습니다...
#
# init_1은 그렇습니다. 네. 제 실수입니다.
# 그리고 loss에 name을 안주었더니 Square로 나오고 있는 것을 볼 수 있습니다.

# %% [markdown]
# <img src="./images/linear.png">

# %% [markdown]
# trainable를 False로 두면...?

# %%
X = tf.placeholder(tf.float32, name='x')
Y = tf.placeholder(tf.float32, name='y')

w = tf.Variable(0.0, name='w', trainable=False)
b = tf.Variable(0.0, name='b')

y_predicted = w * X + b

loss = tf.square(Y - y_predicted)

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001).minimize(loss)

with tf.Session() as sess:
    # Step 7: initialize the necessary variables, in this case, w and b
    # TODO
    sess.run(tf.global_variables_initializer())
    
    for i in range(100):
        total_loss = 0
        for x, y in data:
            # Session runs optimizer to minimize loss and fetch the value of loss
            # TODO
            _, l = sess.run([optimizer, loss], feed_dict={X:x, Y:y})
            
            total_loss += l
        print ('Epoch {0}: {1}'.format(i, total_loss/n_samples))
    
    w_v, b_v = sess.run([w, b])
# Out:
# Epoch 0: 1564.7331783771515
# Epoch 1: 1403.0822174918085
# Epoch 2: 1266.4386564663478
# Epoch 3: 1150.9327962802988
# Epoch 4: 1053.2938449205387
# Epoch 5: 970.75700681834
# Epoch 6: 900.9858744079136
# Epoch 7: 842.0051413778039
# Epoch 8: 792.1452742325408
# Epoch 9: 749.9951012304851
# Epoch 10: 714.3620197460765
# Epoch 11: 684.2379379017012
# Epoch 12: 658.7705174803823
# Epoch 13: 637.2395184232876
# Epoch 14: 619.0359733601412
# Epoch 15: 603.6454096237818
# Epoch 16: 590.6327027694455
# Epoch 17: 579.6301338190124
# Epoch 18: 570.3268665176417
# Epoch 19: 562.4603084863716
# Epoch 20: 555.8082374064695
# Epoch 21: 550.1829568374725
# Epoch 22: 545.425767850663
# Epoch 23: 541.4025064043124
# Epoch 24: 537.9997592307627
# Epoch 25: 535.1216517562667
# Epoch 26: 532.6870692164105
# Epoch 27: 530.6276196306128
# Epoch 28: 528.8853705073042
# Epoch 29: 527.4113194873069
# Epoch 30: 526.164127537271
# Epoch 31: 525.108674309793
# Epoch 32: 524.2154765249718
# ...

# %%
w_v, b_v
# Out:
# (0.0, 33.622688)

# %% [markdown]
# w_v가 0으로 고정...
#
# w, b가 둘다 false면
# optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001).minimize(loss) 여기서 value error가 발생

# %%
def huber_loss(labels, predictions, delta=1.0):
    residual = tf.abs(predictions - labels)
    condition = tf.less(residual, delta)
    small_res = 0.5 * tf.square(residual)
    large_res = delta * residual - 0.5 * tf.square(delta)
    return tf.select(condition, small_res, large_res)

# %% [markdown]
# The Huber loss is basically a compromise between absolute loss and squared loss
#
# Huber loss function is quadratic for residuals smaller then a certain value, and linear for residuals larger then that certain value.
#
# 쓸 줄은 모르겠음

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# https://github.com/chiphuyen/tf-stanford-tutorials/blob/master/examples/03_logistic_regression_mnist_starter.py

# %%
"""
Starter code for logistic regression model to solve OCR task 
with MNIST in TensorFlow
MNIST dataset: yann.lecun.com/exdb/mnist/
"""

import tensorflow as tf
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import time

# Define paramaters for the model
learning_rate = 0.01
batch_size = 128
n_epochs = 10

# Step 1: Read in data
# using TF Learn's built in function to load MNIST data to the folder data/mnist
mnist = input_data.read_data_sets('/data/mnist', one_hot=True) 

# Step 2: create placeholders for features and labels
# each image in the MNIST data is of shape 28*28 = 784
# therefore, each image is represented with a 1x784 tensor
# there are 10 classes for each image, corresponding to digits 0 - 9. 


# Step 3: create weights and bias
# weights and biases are initialized to 0
# shape of w depends on the dimension of X and Y so that Y = X * w + b
# shape of b depends on Y


# Step 4: build model
# the model that returns the logits.
# this logits will be later passed through softmax layer
# to get the probability distribution of possible label of the image
# DO NOT DO SOFTMAX HERE


# Step 5: define loss function
# use cross entropy loss of the real labels with the softmax of logits
# use the method:
# tf.nn.softmax_cross_entropy_with_logits(logits, Y)
# then use tf.reduce_mean to get the mean loss of the batch


# Step 6: define training op
# using gradient descent to minimize loss


with tf.Session() as sess:
	start_time = time.time()
	sess.run(tf.global_variables_initializer())	
	n_batches = int(mnist.train.num_examples/batch_size)
	for i in range(n_epochs): # train the model n_epochs times
		total_loss = 0

		for _ in range(n_batches):
			X_batch, Y_batch = mnist.train.next_batch(batch_size)
			# TO-DO: run optimizer + fetch loss_batch
			# 
			# 
			total_loss += loss_batch
		print 'Average loss epoch {0}: {1}'.format(i, total_loss/n_batches)

	print 'Total time: {0} seconds'.format(time.time() - start_time)

	print('Optimization Finished!') # should be around 0.35 after 25 epochs

	# test the model
	n_batches = int(mnist.test.num_examples/batch_size)
	total_correct_preds = 0
	for i in range(n_batches):
		X_batch, Y_batch = mnist.test.next_batch(batch_size)
		_, loss_batch, logits_batch = sess.run([optimizer, loss, logits], feed_dict={X: X_batch, Y:Y_batch}) 
		preds = tf.nn.softmax(logits_batch)
		correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(Y_batch, 1))
		accuracy = tf.reduce_sum(tf.cast(correct_preds, tf.float32)) # need numpy.count_nonzero(boolarr) :(
		total_correct_preds += sess.run(accuracy)	
	
	print 'Accuracy {0}'.format(total_correct_preds/mnist.test.num_examples)

# %% [markdown]
# ## 이것도 해봅시다...

# %%
import tensorflow as tf
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import time

# Define paramaters for the model
learning_rate = 0.01
batch_size = 128
n_epochs = 10

# %% [markdown]
# ## Step 1: Read in data
# ### using TF Learn's built in function to load MNIST data to the folder data/mnist

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/mnist", one_hot=True)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting data/mnist/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting data/mnist/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting data/mnist/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting data/mnist/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Step 2: create placeholders for features and labels
# ### each image in the MNIST data is of shape 28*28 = 784
# ### therefore, each image is represented with a 1x784 tensor
# ### there are 10 classes for each image, corresponding to digits 0 - 9.

# %%
X = tf.placeholder(tf.float32, [batch_size, 784], name="image")
Y = tf.placeholder(tf.float32, [batch_size, 10], name="label")

# %% [markdown]
# ## Step 3: create weights and bias
# ### weights and biases are initialized to 0
# ### shape of w depends on the dimension of X and Y so that Y = X * w + b
# ### shape of b depends on Y
#
# ### tf.Variable(initial_value=None, trainable=True, collections=None,name=None, dtype=None, ...)

# %%
#w = tf.Variable(0.0)
w = tf.Variable(tf.zeros([784, 10]))
b = tf.Variable(0.0)

#https://www.tensorflow.org/programmers_guide/variables
#weights = tf.Variable(tf.random_normal([784, 200], stddev=0.35),name="weights")

# %% [markdown]
# ## Step 4: build model
# ### the model that returns the logits.
# ### this logits will be later passed through softmax layer
# ### to get the probability distribution of possible label of the image
# ### DO NOT DO SOFTMAX HERE

# %%
#logits = X * w + b
logits = tf.matmul(X, w) + b

# %% [markdown]
# ## Step 5: define loss function
# ### use cross entropy loss of the real labels with the softmax of logits
# ### use the method:
# ### tf.nn.softmax_cross_entropy_with_logits(logits, Y)
# ### then use tf.reduce_mean to get the mean loss of the batch

# %%
#entropy = tf.nn.softmax_cross_entropy_with_logits(logits, Y)
#ValueError: Only call `softmax_cross_entropy_with_logits` with named arguments (labels=..., logits=..., ...)

#entropy = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=Y)
#ValueError: Dimension 1 in both shapes must be equal, but are 784 and 10 for 'SoftmaxCrossEntropyWithLogits' (op: 'SoftmaxCrossEntropyWithLogits') with input shapes: [128,784], [128,10].

# %% [markdown]
# w 다시 만들고,
# logits 다시 만듬...

# %%
entropy = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=Y)

# %%
loss = tf.reduce_mean(entropy)

# %% [markdown]
# ## Step 6: define training op
# ### using gradient descent to minimize loss

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001).minimize(loss)

# %% [markdown]
# ## Phase 2

# %%
with tf.Session() as sess:
    start_time = time.time()
    sess.run(tf.global_variables_initializer())	
    n_batches = int(mnist.train.num_examples/batch_size)
    for i in range(n_epochs): # train the model n_epochs times
        total_loss = 0

        for _ in range(n_batches):
            X_batch, Y_batch = mnist.train.next_batch(batch_size)
            # TO-DO: run optimizer + fetch loss_batch

            _, loss_batch = sess.run([optimizer, loss], feed_dict={X: X_batch, Y:Y_batch})
            
            total_loss += loss_batch
        print ('Average loss epoch {0}: {1}'.format(i, total_loss/n_batches))

    print ('Total time: {0} seconds'.format(time.time() - start_time))

    print ('Optimization Finished!') # should be around 0.35 after 25 epochs

    # test the model
    n_batches = int(mnist.test.num_examples/batch_size)
    total_correct_preds = 0
    for i in range(n_batches):
        X_batch, Y_batch = mnist.test.next_batch(batch_size)
        _, loss_batch, logits_batch = sess.run([optimizer, loss, logits], feed_dict={X: X_batch, Y:Y_batch}) 
        preds = tf.nn.softmax(logits_batch)
        correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(Y_batch, 1))
        accuracy = tf.reduce_sum(tf.cast(correct_preds, tf.float32)) # need numpy.count_nonzero(boolarr) :(
        total_correct_preds += sess.run(accuracy)	

    print ('Accuracy {0}'.format(total_correct_preds/mnist.test.num_examples))
# Out:
# Average loss epoch 0: 2.0973173496606465
# Average loss epoch 1: 1.765452727571234
# Average loss epoch 2: 1.5248144434326456
# Average loss epoch 3: 1.3485869663856525
# Average loss epoch 4: 1.2168592689754245
# Average loss epoch 5: 1.1161385042406184
# Average loss epoch 6: 1.0367658714870196
# Average loss epoch 7: 0.9730883164283557
# Average loss epoch 8: 0.9207131217965435
# Average loss epoch 9: 0.8770742894330502
# Total time: 10.595093011856079 seconds
# Optimization Finished!
# Accuracy 0.8428
